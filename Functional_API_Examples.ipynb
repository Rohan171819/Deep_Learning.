# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan171819/Deep_Learning./blob/main/Functional_API_Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import *

# %%
model=Model(inputs=[Input1,Input2],outputs=Output_Layer)

# %%
Input1=Input(shape=(32,))
Input2=Input(shape=(128,))

# %%
Dense1=Dense(8,activation="relu")(Input1)
Dense2=Dense(4,activation="relu")(Dense1)
Dense3=Dense(64,activation="relu")(Input2)
Dense4=Dense(32,activation="relu")(Dense3)
Dense5=Dense(4,activation="relu")(Dense4)

# %%
# Combining the layers...
Concatenate_1=concatenate([Dense2,Dense5])

# %%
Dense6=Dense(2,activation="relu")(Concatenate_1)
Output_Layer=Dense(1,activation="sigmoid")(Dense6)

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)
